# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from scipy.stats import linregress

# %%
data_clients = pd.read_csv('base_comptoir_espace_table_clients.csv',sep=';')
data_dec_entreprises=pd.read_csv('base_comptoir_espace_table_decisions_entreprises.csv',sep=';')

# %%
###Diagrammes circulaires Répartition clientèle 
produit_choisi=1
annee_choisie=1

# %%
###DIAGRAMMES BARRES CA 2 ANNEES
#Retrouver un tableau donnant les chiffres d'affaires voulus


#Aide pour la réalisation du graphique
'''fig, ax=plt.subplots()
width=0.3
ax.bar(....,-width,align='edge',label='Année 1')
ax.bar(....,width,align='edge',label='Année 2')
ax.set_xticks(....) #Pour changer les étiquettes sur les abscisses
ax.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x,p:format(int(x),',').replace(',',' ')))#Pour changer le format des étiquettes sur les ordonnées (pas à savoir faire)'''
# Out:
# "fig, ax=plt.subplots()\nwidth=0.3\nax.bar(....,-width,align='edge',label='Année 1')\nax.bar(....,width,align='edge',label='Année 2')\nax.set_xticks(....) #Pour changer les étiquettes sur les abscisses\nax.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x,p:format(int(x),',').replace(',',' ')))#Pour changer le format des étiquettes sur les ordonnées (pas à savoir faire)"

# %%
###HISTOGRAMMES PRIX ATTENDUS POUR UN PRODUIT SUR UNE ANNEE
produit_choisi=1
annee_choisie=1
#Rappel : la fonction plt.hist effectue elle-même le calcul des effectifs à l'intérieur des intervalles qu'on peut spécifier 
#ou qui sont calculés en en donnant le nombre (dans les deux cas on renseigne le paramètres bins). On peut par ailleurs récupérer les effectifs
#via effectifs,_,_=plt.hist(...)

#Aide pour générer ces intervalles : par exemple avec des valeurs qui iraient de 22.3 à 113 et qu'on souhaitait des intervalles d'amplitude 5 de 20 
#à 113 on peut remarquer que 22/5 nous donne le nombre de "cinquaines" à arrondir à l'unité inférieure pour avoir ensuite le premier multiple de cinq directement inférieur
# Les intervalles vont donc de int(22.3/5)*5 à (int(113/5)+1)*5

#Pour mieux comparer les clientèles des différentes entreprises on souhaite avoir la même échelle et les mêmes graduations qu'on déterminera
#Cela peut se faire en utilisant :
#ax.set_yticks(liste des graduations)
#ax.set_ybound(min echelle, max echelle)

# %%
produit_choisi=1
annee_choisie=1
data_ann=data_clients[data_clients['CLI_ANNEE']==annee_choisie]
data_pro_choi = data_ann[data_ann['CLI_PROD']==produit_choisi]

data_prix = data_pro_choi['CLI_PRIX']
data_conf = data_pro_choi['CLI_CONFORT']
plt.plot([data_prix.min(),data_prix.max()] , [(data_prix.min()*0.12)+234.98, (data_prix.max()*0.12)+234.98] ,color='red' ,marker='o',markersize=2)

# %%
###Nuage de points Prix/Confort
produit_choisi=2
annee_choisie=1
data_org_an1 = data_clients[data_clients['CLI_ANNEE']==annee_choisie]
data_org_an1 = data_org_an1[data_org_an1['CLI_PROD']==produit_choisi]
data_prix = data_org_an1['CLI_PRIX']
data_confor = data_org_an1['CLI_CONFORT']


plt.scatter(data_prix,data_confor)
plt.xlabel('prix')
plt.ylabel('confort')


#Pour représenter la droite :
res_reg=linregress( data_prix, data_confor)
a=res_reg.slope
b=res_reg.intercept
coef_cor=res_reg.rvalue


#La droite peut être obtenue en calculant le confort attendu d'après le modèle en fonction du prix attendu (on peut se contenter de le faire
# pour deux points en choisissant les prix extrêmes attendus par la clientèle)

#Pour représenter les points montrant les positionnements des différentes entreprises :
#On peut faire une boucle sur l'ensemble des entreprises concernées par la commercialisation d'un voyage en utilisant une couleur différente pour
#chaque entreprise
couleurs = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral','red','green']
plt.plot([data_prix.min(),data_prix.max()] , [(data_prix.min()*0.12)+234.98, (data_prix.max()*0.12)+370.53] ,color='red' ,marker='o',markersize=2)
'''plt.text(... , ... ,'Ent'+str( ... ))'''
# Out:
# "plt.text(... , ... ,'Ent'+str( ... ))"

# %%
"""produit_choisi=2
annee_choisie=1"""
data_1 = data_clients[data_clients['CLI_CHOIX']!=0]
data_1 = data_1[data_clients['CLI_ANNEE']==1]
data_1 = data_1[data_clients['CLI_PROD']==1]

grou_data =data_1.groupby(['CLI_CHOIX']).count()
plt.title("parts de marché sur l'année 1 en qualité des différents entreprises sur le produit 1")
liste_labels=['Entrep'+str(el) for el in grou_data.index.values]
plt.pie(grou_data['CLI_PROD'],labels =liste_labels ,autopct='%.1f%%')

plt.show()

print(data_clients)
n=10
p1=0.4
p2=0.6
width=0.5
data_chiffre_affaire = data_clients[data_clients['CLI_CHOIX']!=0]
data_chiffre_affaire = data_1[data_clients['CLI_ANNEE']==1]

marge_dat_entre = pd.merge(data_clients,data_dec_entreprises,left_on = ['CLI_PROD','CLI_ANNEE','CLI_CHOIX'],right_on=['ENT_PROD',"ENT_ANNEE"],how='inner')

grou_data_chiffre_affaire =data_chiffre_affaire.groupby(['CLI_PRIX']).sum()

'''nav1=pd.Series(st.binom.rvs(n,p1,size=data_chiffre_affaire.size),name='année 1')
group_nav1=nav1.groupby(nav1).count()

nav2=pd.Series(st.binom.rvs(n,p2,size=data_chiffre_affaire.size),name='année 2')
group_nav2=nav2.groupby(nav2).count()'''


"""print(nav1)

plt.bar(group_nav1.index.values,group_nav1,-width,align='edge',label='CLI_ANNEE')
plt.bar(group_nav2.index.values,group_nav2,width,align='edge',label='CLI_ANNEE')
plt.legend()"""
print("******************")
print(data_clients)
print("******************")
print(data_dec_entreprises)
print("**********JOINTURE*********",grou_data_chiffre_affaire)
# Out:
# C:\Users\chams\AppData\Local\Temp\ipykernel_8900\363533643.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data_1 = data_1[data_clients['CLI_ANNEE']==1]
# C:\Users\chams\AppData\Local\Temp\ipykernel_8900\363533643.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data_1 = data_1[data_clients['CLI_PROD']==1]
# C:\Users\chams\AppData\Local\Temp\ipykernel_8900\363533643.py:20: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data_chiffre_affaire = data_1[data_clients['CLI_ANNEE']==1]
#           CLI_ID  CLI_ANNEE  CLI_PROD  CLI_PRIX  CLI_CONFORT  CLI_COM  \
# 0          CLI_1          1         1     10500         1650        2
# 1          CLI_2          1         1      8100         1150        1
# 2          CLI_3          1         2      6300          800        5
# 3          CLI_4          1         2     11400         1550        4
# 4          CLI_5          1         1      6600         1300        1
# ...          ...        ...       ...       ...          ...      ...
# 19995  CLI_19996          2         1      7900         1300        3
# 19996  CLI_19997          2         1      7800         1050        2
# 19997  CLI_19998          2         1     10800         1450        3
# 19998  CLI_19999          2         1      5800          800        1
# 19999  CLI_20000          2         1     10600         1500        1
#
#        CLI_CHOIX  CLI_AGE CLI_GENRE
# 0              1       51         M
# 1              2       44         M
# 2              0       26         F
# 3              0       35         F
# 4              4       47         M
# ...          ...      ...       ...
# 19995          1       37         F
# 19996          4       36         M
# 19997          4       41         M
# 19998          2       35         F
# 19999          0       47         F
#
# [20000 rows x 9 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 22
#      18 width=0.5
#      19 data_chiffre_affaire = data_clients[data_clients['CLI_CHOIX']!=0]
#      20 data_chiffre_affaire = data_1[data_clients['CLI_ANNEE']==1]
#      21
# ---> 22 marge_dat_entre = pd.merge(data_clients,data_dec_entreprises,left_on = ['CLI_PROD','CLI_ANNEE','CLI_CHOIX'],right_on=['ENT_PROD',"ENT_ANNEE"],how='inner')
#      23
#      24 grou_data_chiffre_affaire =data_chiffre_affaire.groupby(['CLI_PRIX']).sum()
#      25
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\reshape\merge.py:385, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     371     return _cross_merge(
#     372         left_df,
#     373         right_df,
#    (...)    382         validate=validate,
#     383     )
#     384 else:
# --> 385     op = _MergeOperation(
#     386         left_df,
#     387         right_df,
#     388         how=how,
#     389         on=on,
#     390         left_on=left_on,
#     391         right_on=right_on,
#     392         left_index=left_index,
#     393         right_index=right_index,
#     394         sort=sort,
#     395         suffixes=suffixes,
#     396         indicator=indicator,
#     397         validate=validate,
#     398     )
#     399     return op.get_result()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\reshape\merge.py:1010, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#    1003     msg = (
#    1004         "Not allowed to merge between different levels. "
#    1005         f"({_left.columns.nlevels} levels on the left, "
#    1006         f"{_right.columns.nlevels} on the right)"
#    1007     )
#    1008     raise MergeError(msg)
# -> 1010 self.left_on, self.right_on = self._validate_left_right_on(left_on, right_on)
#    1012 (
#    1013     self.left_join_keys,
#    1014     self.right_join_keys,
#    (...)   1017     right_drop,
#    1018 ) = self._get_merge_keys()
#    1020 if left_drop:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\reshape\merge.py:1959, in _MergeOperation._validate_left_right_on(self, left_on, right_on)
#    1957         left_on = [None] * n
#    1958 if len(right_on) != len(left_on):
# -> 1959     raise ValueError("len(right_on) must equal len(left_on)")
#    1961 return left_on, right_on
#
# ValueError: len(right_on) must equal len(left_on)
